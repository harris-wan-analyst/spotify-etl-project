# %%
import spotipy
from spotipy.oauth2 import SpotifyClientCredentials
import pandas as pd

# %%
# For Authentication
client_credentials_manager = SpotifyClientCredentials(client_id=client_id, client_secret=client_secret)

# %%
# For Authorisation (permission to access the Spotify API)
sp = spotipy.Spotify(client_credentials_manager = client_credentials_manager)

# %%
playlist_link = "https://open.spotify.com/playlist/37i9dQZEVXbNG2KDcFcKOF?si=1333723a6eff4b7f&nd=1&dlsi=78c8442206dc4eb5"

# %%
# Extract playlist information
playlist_URI = playlist_link.split("/")[-1].split("?")[0]

# %%
data = sp.playlist_tracks(playlist_URI)

# %%
# Album information
data['items']
# Out:
# [{'added_at': '2024-04-12T10:07:58Z',
#   'added_by': {'external_urls': {'spotify': 'https://open.spotify.com/user/'},
#    'href': 'https://api.spotify.com/v1/users/',
#    'id': '',
#    'type': 'user',
#    'uri': 'spotify:user:'},
#   'is_local': False,
#   'primary_color': None,
#   'track': {'album': {'album_type': 'single',
#     'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/0PCCGZ0wGLizHt2KZ7hhA2'},
#       'href': 'https://api.spotify.com/v1/artists/0PCCGZ0wGLizHt2KZ7hhA2',
#       'id': '0PCCGZ0wGLizHt2KZ7hhA2',
#       'name': 'Artemas',
#       'type': 'artist',
#       'uri': 'spotify:artist:0PCCGZ0wGLizHt2KZ7hhA2'}],
#     'available_markets': ['AR',
#      'AU',
#      'AT',
#      'BE',
#      'BO',
#      'BR',
#      'BG',
#      'CA',
#      'CL',
#      'CO',
#      'CR',
#      'CY',
#      'CZ',
#      'DK',
#      'DO',
#      'DE',
#      'EC',
#      'EE',
#      'SV',
#      'FI',
#      'FR',
#      'GR',
#      'GT',
# ...

# %%
# Album ID
data['items'][0]['track']['album']['id']
# Out:
# '5HIWDdg3g9CTOtnevKDl1z'

# %%
# Album Name
data['items'][0]['track']['album']['name']
# Out:
# 'i like the way you kiss me'

# %%
 # Album Release Date
data['items'][0]['track']['album']['release_date']
# Out:
# '2024-03-19'

# %%
# Album Total Tracks
data['items'][0]['track']['album']['total_tracks']
# Out:
# 1

# %%
# Album External URLs
data['items'][0]['track']['album']['external_urls']['spotify']
# Out:
# 'https://open.spotify.com/album/5HIWDdg3g9CTOtnevKDl1z'

# %%
album_list = []

for row in data['items']:
    album_id = row['track']['album']['id']
    album_name = row['track']['album']['name']
    album_release_date = row['track']['album']['release_date']
    album_total_tracks = row['track']['album']['total_tracks']
    album_url = row['track']['album']['external_urls']['spotify']
    album_element = {'album_id':album_id,'name':album_name,'release_date':album_release_date,
                        'total_tracks':album_total_tracks,'url':album_url}
    album_list.append(album_element)

# %%
artist_list = []

for row in data['items']:
    for key, value in row.items():
        if key == 'track':
            for artist in value['artists']:
                artist_dict = {'artist_id':artist['id'], 'artist_name':artist['name'], 'external_url': artist['href']}
                artist_list.append(artist_dict)

# %%
song_list = []

for row in data['items']:
    song_id = row['track']['id']
    song_name = row['track']['name']
    song_duration = row['track']['duration_ms']
    song_url = row['track']['external_urls']['spotify']
    song_popularity = row['track']['popularity']
    song_added = row['added_at']
    album_id = row['track']['album']['id']
    artist_id = row['track']['album']['artists'][0]['id']
    song_element = {'song_id':song_id,'song_name':song_name,'duration_ms':song_duration,'url':song_url,
                    'popularity':song_popularity,'song_added':song_added,'album_id':album_id,
                    'artist_id':artist_id
                   }
    song_list.append(song_element)

# %%
def list_to_df(x):
    df = pd.DataFrame.from_dict(x)
    df = df.drop_duplicates(subset=df.columns[0])
    df = df.head()
    return df

# %%
list_to_df(album_list)
# Out:
#                  album_id                        name release_date  \
# 0  5HIWDdg3g9CTOtnevKDl1z  i like the way you kiss me   2024-03-19
# 1  1vL2mgGTukkrUxXt0loeTN     Unreal Unearth: Unheard   2024-03-22
# 2  168CdR21lfn0TTyw1Pkdcm    Fireworks & Rollerblades   2024-04-05
# 3  4JDXBZdRPId4devseaAOKH                      DECIDE   2022-09-16
# 4  5EYKrEDnKhhcNxGedaRQeK            eternal sunshine   2024-03-08
#
#    total_tracks                                                url
# 0             1  https://open.spotify.com/album/5HIWDdg3g9CTOtn...
# 1            20  https://open.spotify.com/album/1vL2mgGTukkrUxX...
# 2            15  https://open.spotify.com/album/168CdR21lfn0TTy...
# 3            13  https://open.spotify.com/album/4JDXBZdRPId4dev...
# 4            13  https://open.spotify.com/album/5EYKrEDnKhhcNxG...

# %%
list_to_df(artist_list)
# Out:
#                 artist_id    artist_name  \
# 0  0PCCGZ0wGLizHt2KZ7hhA2        Artemas
# 1  2FXC3k01G6Gw61bmprjgqS         Hozier
# 2  22wbnEMDvgVIAGdFeek6ET   Benson Boone
# 3  5p9HO3XC5P3BLxJs5Mtrhm            Djo
# 4  66CXWjxzNUsdJxJ2JdwvnR  Ariana Grande
#
#                                         external_url
# 0  https://api.spotify.com/v1/artists/0PCCGZ0wGLi...
# 1  https://api.spotify.com/v1/artists/2FXC3k01G6G...
# 2  https://api.spotify.com/v1/artists/22wbnEMDvgV...
# 3  https://api.spotify.com/v1/artists/5p9HO3XC5P3...
# 4  https://api.spotify.com/v1/artists/66CXWjxzNUs...

# %%
list_to_df(song_list)
# Out:
#                   song_id                                 song_name  \
# 0  2GxrNKugF82CnoRFbQfzPf                i like the way you kiss me
# 1  0AjmK0Eai4zGrLaJwPvrDp                                 Too Sweet
# 2  3xkHsmpQCBMytMJNiDf3Ii                          Beautiful Things
# 3  3qhlB30KknSejmIvZZLjOD                          End of Beginning
# 4  51ZQ1vr10ffzbwIjDCwqm4  we can't be friends (wait for your love)
#
#    duration_ms                                                url  popularity  \
# 0       142514  https://open.spotify.com/track/2GxrNKugF82CnoR...          97
# 1       251424  https://open.spotify.com/track/0AjmK0Eai4zGrLa...          85
# 2       180304  https://open.spotify.com/track/3xkHsmpQCBMytMJ...          80
# 3       159245  https://open.spotify.com/track/3qhlB30KknSejmI...          99
# 4       228639  https://open.spotify.com/track/51ZQ1vr10ffzbwI...          95
#
#              song_added                album_id               artist_id
# ...
